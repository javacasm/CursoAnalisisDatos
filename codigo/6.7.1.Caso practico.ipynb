# %% [markdown]
# # Ejemplo práctico

# %%
# Descargamos los datos de https://www.kaggle.com/datasets/rohitsahoo/sales-forecasting
# Los descomprimimos
# fichero 'SuperStore_Sales_Dataset.csv'

# %%
import pandas as pd

df = pd.read_csv('SuperStore_Sales_Dataset.csv')
df
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 0      Gaithersburg  ...        Furniture    Bookcases
# 1      Gaithersburg  ...        Furniture    Bookcases
# 2      Gaithersburg  ...       Technology       Phones
# 3       Los Angeles  ...  Office Supplies      Storage
# 4       San Antonio  ...       Technology  Accessories
# ...             ...  ...              ...          ...
# 5896  New York City  ...        Furniture    Bookcases
# 5897      Fairfield  ...  Office Supplies      Binders
# 5898       Loveland  ...  Office Supplies    Fasteners
# 5899  New York City  ...  Office Supplies      Binders
# 5900       Loveland  ...  Office Supplies    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                   Imation Clip USB flash drive - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit  Returns  Payment Mode  ind1  ind2
# 0     28.2668      NaN        Online   NaN   NaN
# 1     38.2668      NaN        Online   NaN   NaN
# 2     67.2742      NaN         Cards   NaN   NaN
# 3     28.6150      NaN        Online   NaN   NaN
# 4     -5.2640      NaN        Online   NaN   NaN
# ...       ...      ...           ...   ...   ...
# 5896  12.1176      NaN           COD   NaN   NaN
# 5897   4.5188      1.0        Online   NaN   NaN
# 5898  -0.6048      NaN        Online   NaN   NaN
# 5899  19.7910      NaN           COD   NaN   NaN
# 5900  -0.6048      NaN           COD   NaN   NaN
#
# [5901 rows x 23 columns]

# %% [markdown]
# ## Revisión de datos

# %%
# Examinamos los datos
print("Primeras 5 filas:\n", df.head())
# Out:
# Primeras 5 filas:
#     Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture    Bookcases
# 2       Technology       Phones
# 3  Office Supplies      Storage
# 4       Technology  Accessories
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
# 2                                        GE 30522EE2  231.98        2
# 3  Recycled Steel Personal File for Hanging File ...  114.46        2
# 4                Imation Clip USB flash drive - 8 GB   30.08        2
#
#     Profit  Returns  Payment Mode  ind1  ind2
# 0  28.2668      NaN        Online   NaN   NaN
# 1  38.2668      NaN        Online   NaN   NaN
# 2  67.2742      NaN         Cards   NaN   NaN
# 3  28.6150      NaN        Online   NaN   NaN
# 4  -5.2640      NaN        Online   NaN   NaN
#
# [5 rows x 23 columns]

# %%
print("Información general:\n")
print("Forma del dataset:", df.shape)  # Ej: (9994, 17)
print("Columnas:", df.columns.tolist())
print("\nTipos de datos:\n", df.dtypes)
# Out:
# Información general:
#
# Forma del dataset: (5901, 23)
# Columnas: ['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1', 'ind2']
#
# Tipos de datos:
#  Row ID+O6G3A1:R6      int64
# Order ID             object
# Order Date           object
# Ship Date            object
# Ship Mode            object
# Customer ID          object
# Customer Name        object
# Segment              object
# Country              object
# City                 object
# State                object
# Region               object
# Product ID           object
# Category             object
# Sub-Category         object
# Product Name         object
# Sales               float64
# Quantity              int64
# Profit              float64
# Returns             float64
# Payment Mode         object
# ind1                float64
# ind2                float64
# dtype: object

# %%
print("\nEstadísticas descriptivas de columnas numéricas:\n", df.describe())
# Out:
# Estadísticas descriptivas de columnas numéricas:
#         Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %% [markdown]
# ## Limpieza de datos

# %%
# Limpieza de datos
print("Duplicados:", df.duplicated().sum())
# Out:
# Duplicados: 0

# %%
print("Valores nulos por columna:\n", df.isnull().sum())
# Out:
# Valores nulos por columna:
#  Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
# Convertir fechas
df['Order Date'] = pd.to_datetime(df['Order Date'],format='%d-%m-%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format='%d-%m-%Y')
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df
# Out:
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0                 4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1                 4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2                 4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3                 3074  CA-2019-125206 2019-01-03 2019-01-05     First Class
# 4                 8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
# ...                ...             ...        ...        ...             ...
# 5896               907  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5897              1297  CA-2020-115427 2020-12-30 2021-01-03  Standard Class
# 5898              5092  CA-2020-156720 2020-12-30 2021-01-03  Standard Class
# 5899               909  CA-2020-143259 2020-12-30 2021-01-03  Standard Class
# 5900              5093  CA-2020-151450 2020-12-31 2021-01-04  Standard Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 0       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 1       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 2       BM-11575      Brendan Murry  Corporate  United States   Gaithersburg
# 3       LR-16915       Lena Radford   Consumer  United States    Los Angeles
# 4       CA-12310  Christine Abelman  Corporate  United States    San Antonio
# ...          ...                ...        ...            ...            ...
# 5896    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 5897    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 5898    JM-15580      Jill Matthias   Consumer  United States       Loveland
# 5899    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 5900    JM-15580      Jill Matthias   Consumer  United States       Loveland
#
#       ...                                       Product Name     Sales  \
# 0     ...  Bush Westfield Collection Bookcases, Medium Ch...    73.940
# 1     ...  Bush Westfield Collection Bookcases, Medium Ch...   173.940
# 2     ...                                        GE 30522EE2   231.980
# 3     ...  Recycled Steel Personal File for Hanging File ...   114.460
# 4     ...                Imation Clip USB flash drive - 8 GB    30.080
# ...   ...                                                ...       ...
# 5896  ...  Bush Westfield Collection Bookcases, Fully Ass...   213.136
# 5897  ...    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904
# 5898  ...                                Bagged Rubber Bands   388.024
# 5899  ...               Wilson Jones Legal Size Ring Binders   462.776
# 5900  ...                                Bagged Rubber Bands  2975.510
#
#      Quantity   Profit Returns Payment Mode  ind1  ind2  Year  Month
# 0           1  28.2668     NaN       Online   NaN   NaN  2019      1
# 1           3  38.2668     NaN       Online   NaN   NaN  2019      1
# 2           2  67.2742     NaN        Cards   NaN   NaN  2019      1
# 3           2  28.6150     NaN       Online   NaN   NaN  2019      1
# 4           2  -5.2640     NaN       Online   NaN   NaN  2019      1
# ...       ...      ...     ...          ...   ...   ...   ...    ...
# 5896        4  12.1176     NaN          COD   NaN   NaN  2020     12
# 5897        2   4.5188     1.0       Online   NaN   NaN  2020     12
# 5898        3  -0.6048     NaN       Online   NaN   NaN  2020     12
# 5899        3  19.7910     NaN          COD   NaN   NaN  2020     12
# 5900        3  -0.6048     NaN          COD   NaN   NaN  2020     12
#
# [5901 rows x 25 columns]

# %% [markdown]
# ## Detectar valores atípicos

# %%
# Detectar outliers en Sales (usando IQR)
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1
limite_superior = Q3 + 1.5 * IQR
outliers_sales = df[df['Sales'] > limite_superior]
print("Outliers en Sales:", len(outliers_sales))  # Ej: ~500
outliers_sales
# Out:
# Outliers en Sales: 631
#       Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 7                 9494  CA-2019-105207 2019-01-03 2019-01-08  Standard Class
# 9                 2898  US-2019-164630 2019-01-04 2019-01-09  Standard Class
# 18                6851  US-2019-100461 2019-01-08 2019-01-12  Standard Class
# 50                2877  US-2019-167339 2019-01-21 2019-01-23    Second Class
# 65                9149  US-2019-165505 2019-01-23 2019-01-27  Standard Class
# ...                ...             ...        ...        ...             ...
# 5856              5475  CA-2020-121741 2020-12-26 2020-12-26        Same Day
# 5860              2570  CA-2020-134404 2020-12-27 2020-12-27        Same Day
# 5861              2571  CA-2020-134404 2020-12-27 2020-12-27        Same Day
# 5875              6820  CA-2020-163860 2020-12-28 2021-01-01  Standard Class
# 5900              5093  CA-2020-151450 2020-12-31 2021-01-04  Standard Class
#
#      Customer ID     Customer Name    Segment        Country          City  \
# 7       BO-11350     Bill Overfelt  Corporate  United States  Broken Arrow
# 9       EB-13975        Erica Bern  Corporate  United States     Charlotte
# 18      JO-15145     Jack O'Briant  Corporate  United States      Franklin
# 50      TD-20995     Tamara Dahlen   Consumer  United States     San Diego
# 65      CB-12535  Claudia Bergmann  Corporate  United States    Burlington
# ...          ...               ...        ...            ...           ...
# 5856    YC-21895    Yoseph Carroll  Corporate  United States       Fremont
# 5860    DR-12880   Dan Reichenbach  Corporate  United States        Newark
# 5861    DR-12880   Dan Reichenbach  Corporate  United States        Newark
# 5875    LO-17170        Lori Olson  Corporate  United States        Peoria
# 5900    JM-15580     Jill Matthias   Consumer  United States      Loveland
#
#       ...                                       Product Name     Sales  \
# 7     ...  Hon Practical Foundations 30 x 60 Training Tab...  1592.850
# 9     ...           Hewlett Packard 310 Color Digital Copier   959.968
# 18    ...  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...  1565.880
# 50    ...                    Global Ergonomic Managers Chair  1013.488
# 65    ...              Iceberg Mobile Mega Data/Printer Cart  1564.290
# ...   ...                                                ...       ...
# 5856  ...                        Tennsco Single-Tier Lockers  1063.680
# 5860  ...                             AT&T 1080 Corded phone   928.388
# 5861  ...                       BIC Brite Liner Highlighters  1267.248
# 5875  ...  G.E. Longer-Life Indoor Recessed Floodlight Bulbs  1302.968
# 5900  ...                                Bagged Rubber Bands  2975.510
#
#      Quantity    Profit Returns Payment Mode  ind1  ind2  Year  Month
# 7           7  350.4270     NaN          COD   NaN   NaN  2019      1
# 9           4  119.9960     NaN       Online   NaN   NaN  2019      1
# 18          6  407.1288     NaN       Online   NaN   NaN  2019      1
# 50          7   76.0116     NaN          COD   NaN   NaN  2019      1
# 65         13  406.7154     NaN       Online   NaN   NaN  2019      1
# ...       ...       ...     ...          ...   ...   ...   ...    ...
# 5856        2   37.5340     NaN       Online   NaN   NaN  2020     12
# 5860        2  -35.6174     NaN          COD   NaN   NaN  2020     12
# 5861        4    3.6432     NaN       Online   NaN   NaN  2020     12
# 5875        3   -2.3904     NaN       Online   NaN   NaN  2020     12
# 5900        3   -0.6048     NaN          COD   NaN   NaN  2020     12
#
# [631 rows x 25 columns]

# %%
# Reemplazar outliers por el límite superior (o eliminar, según criterio)
df['Sales'] = df['Sales'].clip(upper=limite_superior)

# %%
# Crear columna de Profit Margin (para análisis)
df['Profit Margin'] = df['Profit'] / df['Sales'] * 100  # En porcentaje

# %%
# Resultado final
print("Dataset limpio - Forma:", df.shape)
print("Primeras filas después de limpieza:\n", df.head())
# Out:
# Dataset limpio - Forma: (5901, 26)
# Primeras filas después de limpieza:
#     Row ID+O6G3A1:R6        Order ID Order Date  Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304 2019-01-01 2019-01-07  Standard Class
# 1              4919  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 2              4920  CA-2019-160304 2019-01-02 2019-01-07  Standard Class
# 3              3074  CA-2019-125206 2019-01-03 2019-01-05     First Class
# 4              8604  US-2019-116365 2019-01-03 2019-01-08  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#     Sales Quantity   Profit Returns Payment Mode ind1  ind2  Year  Month  \
# 0   73.94        1  28.2668     NaN       Online  NaN   NaN  2019      1
# 1  173.94        3  38.2668     NaN       Online  NaN   NaN  2019      1
# 2  231.98        2  67.2742     NaN        Cards  NaN   NaN  2019      1
# 3  114.46        2  28.6150     NaN       Online  NaN   NaN  2019      1
# 4   30.08        2  -5.2640     NaN       Online  NaN   NaN  2019      1
#
#    Profit Margin
# 0      38.229375
# 1      22.000000
# 2      29.000000
# 3      25.000000
# 4     -17.500000
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Análisis exploratorio y estadístico

# %%
# Estadísticas descriptivas por categoría
print("Ventas por Categoría:\n", df.groupby('Category')['Sales'].agg(['mean', 'sum', 'count']))
# Out:
# Ventas por Categoría:
#                         mean          sum  count
# Category
# Furniture        265.022581  331013.2037   1249
# Office Supplies  141.284788  504245.4080   3569
# Technology       264.131377  286054.2810   1083

# %%
# Correlación entre Sales y Profit
from scipy.stats import pearsonr, linregress, ttest_ind, chi2_contingency
corr, p_value = pearsonr(df['Sales'], df['Profit'])
print(f"Correlación Sales-Profit: {corr:.3f}, p-valor: {p_value:.3f}")
# Out:
# Correlación Sales-Profit: 0.163, p-valor: 0.000

# %%
# Regresión lineal Sales vs Profit
slope, intercept, r_value, p_value, std_err = linregress(df['Sales'], df['Profit'])
print(f"R²: {r_value**2:.3f}")
# Out:
# R²: 0.027

# %%
# T-test: Comparar ganancias promedio por región (ej. Central vs West)
profit_central = df[df['Region'] == 'Central']['Profit']
profit_west = df[df['Region'] == 'West']['Profit']
t_stat, p_value_t = ttest_ind(profit_central, profit_west)
print(f"T-test regiones: t={t_stat:.3f}, p={p_value_t:.3f}")
# Out:
# T-test regiones: t=-1.716, p=0.086

# %%
# Tabla de contingencia y Chi-cuadrado: Segment vs Category
tabla = pd.crosstab(df['Segment'], df['Category'])
chi2, p_value_chi, dof, expected = chi2_contingency(tabla)
print(f"Chi-cuadrado: {chi2:.3f}, p={p_value_chi:.3f}")
# Out:
# Chi-cuadrado: 5.836, p=0.212

# %% [markdown]
# ## Visualización de patrones

# %%
# Gráfico de barras: Ventas por Región
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Region', y='Sales', estimator='mean')
plt.title('Ventas Promedio por Región')
plt.ylabel('Ventas Promedio ($)')
plt.show()

# %%
# Boxplot: Profit por Categoría
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Category', y='Profit')
plt.title('Distribución de Ganancias por Categoría')
plt.show()

# %%
# Heatmap de correlaciones
corr_matrix = df[['Sales', 'Profit', 'Quantity']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# ## Análisis exploratorio

# %%
# Estadísticas descriptivas por categoría
print("Ventas por Categoría:\n", df.groupby('Category')['Sales'].agg(['mean', 'sum', 'count']))
# Out:
# Ventas por Categoría:
#                         mean          sum  count
# Category
# Furniture        265.022581  331013.2037   1249
# Office Supplies  141.284788  504245.4080   3569
# Technology       264.131377  286054.2810   1083

# %%
# Correlación entre Sales y Profit
corr, p_value = pearsonr(df['Sales'], df['Profit'])
print(f"Correlación Sales-Profit: {corr:.3f}, p-valor: {p_value:.3f}")
# Out:
# Correlación Sales-Profit: 0.163, p-valor: 0.000

# %%
slope, intercept, r_value, p_value, std_err = linregress(df['Sales'], df['Profit'])
print(f"R²: {r_value**2:.3f}")
# Out:
# R²: 0.027

# %%
# T-test: Comparar ganancias promedio por región (ej. Central vs West)
profit_central = df[df['Region'] == 'Central']['Profit']
profit_west = df[df['Region'] == 'West']['Profit']
t_stat, p_value_t = ttest_ind(profit_central, profit_west)
print(f"T-test regiones: t={t_stat:.3f}, p={p_value_t:.3f}")
# Out:
# T-test regiones: t=-1.716, p=0.086

# %%
# Tabla de contingencia y Chi-cuadrado: Segment vs Category
tabla = pd.crosstab(df['Segment'], df['Category'])
chi2, p_value_chi, dof, expected = chi2_contingency(tabla)
print(f"Chi-cuadrado: {chi2:.3f}, p={p_value_chi:.3f}")
# Out:
# Chi-cuadrado: 5.836, p=0.212

# %% [markdown]
# ## Visualización de Insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Region', y='Sales', estimator='mean')
plt.title('Ventas Promedio por Región')
plt.ylabel('Ventas Promedio ($)')
plt.show()

# %%
# Boxplot: Profit por Categoría
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Category', y='Profit')
plt.title('Distribución de Ganancias por Categoría')
plt.show()

# %%
# Heatmap de correlaciones
corr_matrix = df[['Sales', 'Profit', 'Quantity']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()

# %%
# Gráfico de líneas: Ventas por Mes (agregado por Año y Mes)
ventas_tiempo = df.groupby(['Year', 'Month'])['Sales'].sum().reset_index()
ventas_tiempo['Date'] = pd.to_datetime(ventas_tiempo[['Year', 'Month']].assign(day=1))
plt.figure(figsize=(12, 6))
plt.plot(ventas_tiempo['Date'], ventas_tiempo['Sales'])
plt.title('Tendencia de Ventas por Tiempo')
plt.xlabel('Fecha')
plt.ylabel('Ventas Totales ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Buenas Prácticas y Optimizaciones
#
# - **Flujo de Trabajo:** Siempre documenta pasos en notebooks (celdas Markdown). Usa `df.pipe()` para encadenar transformaciones.
# - **Escalabilidad:** Para datasets grandes (>1M filas), usa `dask` o `modin` para paralelismo (instala si es necesario, pero no en este curso).
# - **Versionado:** Usa Git para notebooks y datos. Prueba con subconjuntos (`df.sample(1000)`).
# - **Ética:** Verifica sesgos en datos (ej. regiones subrepresentadas) y anonimiza información sensible.
